# %% [markdown]
# Mount drive:

# %%
from google.colab import drive
drive.mount('/content/drive')
# !pwd

# %%
# %cd /content/drive/MyDrive/DAAI/CosPlace
# !pip install -r requirements.txt

# %%
# !pwd
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)

# %% [markdown]
# Train the model on sf-xs:

# %%
# !python train.py --dataset_folder /content/drive/MyDrive/DAAI/dataset/sf-xs/small --groups_num 1 --epochs_num 3

# %% [markdown]
# Test the model on tokyo_night:

# %%
# !python eval.py --dataset_folder /content/drive/MyDrive/DAAI/dataset/tokyo_night --groups_num 1 --epochs_num 3 --resume_model /content/drive/MyDrive/DAAI/CosPlace/logs/default/trained_cosface/best_model.pth

# %% [markdown]
# Test the model on tokyo_xs:

# %%
# !python eval.py --dataset_folder /content/drive/MyDrive/DAAI/dataset/tokyo_xs --groups_num 1 --epochs_num 3 --resume_model /content/drive/MyDrive/CosPlace/logs/default/trained_cosface/best_model.pth

# %% [markdown]
# Train the model with arcface loss

# %%
# !python train_arcface.py --dataset_folder /content/drive/MyDrive/DAAI/dataset/sf-xs/small --groups_num 1 --epochs_num 3

# %% [markdown]
# Test the model on tokyo_night:

# %%
# !python eval.py --dataset_folder /content/drive/MyDrive/DAAI/dataset/tokyo_night --groups_num 1 --epochs_num 3 --resume_model /content/drive/MyDrive/DAAI/CosPlace/logs/default/trained_arcface/best_model.pth

# %% [markdown]
# Test the model on tokyo_xs:

# %%
# !python eval.py --dataset_folder /content/drive/MyDrive/DAAI/dataset/tokyo_xs --groups_num 1 --epochs_num 3 --resume_model /content/drive/MyDrive/DAAI/CosPlace/logs/default/trained_arcface/best_model.pth

# %% [markdown]
# Train the model with different margins of ArcFace:

# %%
#m = 0.55 instead of 0.5
# !python train_arcface.py --dataset_folder /content/drive/MyDrive/DAAI/dataset/sf-xs/small --groups_num 1 --epochs_num 3

# %%
# m = 0.45 instead of 0.5
# !python train_arcface.py --dataset_folder /content/drive/MyDrive/DAAI/dataset/sf-xs/small --groups_num 1 --epochs_num 3

# %% [markdown]
# Train the model with SphereFace loss:

# %%
# !python train_sphereface.py --dataset_folder /content/drive/MyDrive/DAAI/dataset/sf-xs/small --groups_num 1 --epochs_num 3

# %% [markdown]
# Test the model on tokyo_night:

# %%
# !python eval.py --dataset_folder /content/drive/MyDrive/DAAI/dataset/tokyo_night --groups_num 1 --epochs_num 3 --resume_model /content/drive/MyDrive/DAAI/CosPlace/logs/default/trained_sphereface/best_model.pth

# %% [markdown]
# Test the model on tokyo_xs:

# %%
# !python eval.py --dataset_folder /content/drive/MyDrive/DAAI/dataset/tokyo_xs --groups_num 1 --epochs_num 3 --resume_model /content/drive/MyDrive/DAAI/CosPlace/logs/default/trained_sphereface/best_model.pth
